# %%
# %matplotlib inline
from pathlib import Path
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, text, MetaData, Table
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float

# %%
# create engine to hawaii.sqlite
database_path = Path("Resources/hawaii.sqlite")
engine = create_engine(f"sqlite:///{database_path}")

# %%
# reflect an existing database into a new model
variable_base = automap_base()
variable_base.prepare(autoload_with=engine)

# %%
# View all of the classes that automap found
variable_base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
measurement_info = variable_base.classes.measurement
station_info = variable_base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
available_dates = session.query(measurement_info.date).order_by(measurement_info.date.desc())
recent_date = available_dates[0][0]
recent_date
# Out:
# '2017-08-23'

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 
most_recent_date_str = session.query(func.max(measurement_info.date)).scalar()
most_recent_date = datetime.strptime(most_recent_date_str, '%Y-%m-%d')

# Calculate the date one year from the last date in data set.
one_year_ago = most_recent_date - timedelta(days=365)

# Perform a query to retrieve the data and precipitation scores
precipitation_data = session.query(measurement_info.date, measurement_info.prcp).\
    filter(measurement_info.date >= one_year_ago).\
    order_by(measurement_info.date).all()

# Save the query results as a Pandas DataFrame. Explicitly set the column names
dates = [result.date for result in precipitation_data]
precipitation = [result.prcp for result in precipitation_data]

# Sort the dataframe by date
    dates_sorted = sorted(dates)

# Use Pandas Plotting with Matplotlib to plot the data
plt.figure(figsize=(10, 6))
plt.plot(dates_sorted, precipitation)
plt.title('Precipitation Over the Last 12 Months')
plt.xlabel('Date')
plt.ylabel('Precipitation (inches)')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Use Pandas to calculate the summary statistics for the precipitation data

# df = pd.DataFrame(measurement_info, columns=['prcp'])
# summary_stats = df['prcp'].describe()
# print(summary_stats)

prcp_series = pd.Series(prcp_data)
summary_stats = prcp_series.describe()
print(summary_stats)

mkanawat
APP  9:19 PM
Try doing dates_sorted.describe()
# summary_stats = pd.Series(precipitation)
# summary_stats.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 7
#       1 # Use Pandas to calculate the summary statistics for the precipitation data
#       2
#       3 # df = pd.DataFrame(measurement_info, columns=['prcp'])
#       4 # summary_stats = df['prcp'].describe()
#       5 # print(summary_stats)
# ----> 7 prcp_series = pd.Series(prcp_data)
#       8 summary_stats = prcp_series.describe()
#       9 print(summary_stats)
#
# NameError: name 'prcp_data' is not defined

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number of stations in the dataset
# Out:
# [(9,)]

# %%
# Design a query to find the most active stations (i.e. which stations have the most rows?)
# List the stations and their counts in descending order.
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
# Out:
# Text(0.5, 4.183333333333314, 'Temperature')

# %% [markdown]
# # Close Session

# %%
# Close Session
session.close()
